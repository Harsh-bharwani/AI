# %%
import numpy as np   
import pandas as pd
import os

import seaborn as sns
import matplotlib.pyplot as plt   
import matplotlib.style
plt.style.use('classic')

import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
# from imblearn.over_sampling import RandomOverSampler  
# from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
# from imblearn.over_sampling import SMOTE,ADASYN

# %%
df=pd.read_csv("German Credit Dataset.csv")

# %%
df
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0             < 0 DM                     6       critical
# 1         1 - 200 DM                    48           good
# 2            unknown                    12       critical
# 3             < 0 DM                    42           good
# 4             < 0 DM                    24           poor
# ..               ...                   ...            ...
# 995          unknown                    12           good
# 996           < 0 DM                    30           good
# 997          unknown                    12           good
# 998           < 0 DM                    45           good
# 999       1 - 200 DM                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951        < 100 DM         1 - 4 years
# 2               education    2096        < 100 DM         4 - 7 years
# 3    furniture/appliances    7882        < 100 DM         4 - 7 years
# 4                     car    4870        < 100 DM         1 - 4 years
# ..                    ...     ...             ...                 ...
# 995  furniture/appliances    1736        < 100 DM         4 - 7 years
# 996                   car    3857        < 100 DM         1 - 4 years
# 997  furniture/appliances     804        < 100 DM           > 7 years
# 998  furniture/appliances    1845        < 100 DM         1 - 4 years
# 999                   car    4576    100 - 500 DM          unemployed
#
#      percent_of_income  years_at_residence  age other_credit housing  \
# 0                    4                   4   67         none     own
# 1                    2                   2   22         none     own
# 2                    2                   3   49         none     own
# 3                    2                   4   45         none   other
# 4                    3                   4   53         none   other
# ..                 ...                 ...  ...          ...     ...
# 995                  3                   4   31         none     own
# 996                  4                   4   40         none     own
# 997                  4                   4   38         none     own
# 998                  4                   4   23         none   other
# 999                  3                   4   27         none     own
#
#      existing_loans_count         job  dependents phone default
# 0                       2     skilled           1   yes      no
# 1                       1     skilled           1    no     yes
# 2                       1   unskilled           2    no      no
# 3                       1     skilled           2    no      no
# 4                       2     skilled           2    no     yes
# ..                    ...         ...         ...   ...     ...
# 995                     1   unskilled           1    no      no
# 996                     1  management           1   yes      no
# 997                     1     skilled           1    no      no
# 998                     1     skilled           1   yes     yes
# 999                     1     skilled           1    no      no
#
# [1000 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# checking_balance        0
# months_loan_duration    0
# credit_history          0
# purpose                 0
# amount                  0
# savings_balance         0
# employment_duration     0
# percent_of_income       0
# years_at_residence      0
# age                     0
# other_credit            0
# housing                 0
# existing_loans_count    0
# job                     0
# dependents              0
# phone                   0
# default                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   checking_balance      1000 non-null   object
#  1   months_loan_duration  1000 non-null   int64
#  2   credit_history        1000 non-null   object
#  3   purpose               1000 non-null   object
#  4   amount                1000 non-null   int64
#  5   savings_balance       1000 non-null   object
#  6   employment_duration   1000 non-null   object
#  7   percent_of_income     1000 non-null   int64
#  8   years_at_residence    1000 non-null   int64
#  9   age                   1000 non-null   int64
#  10  other_credit          1000 non-null   object
#  11  housing               1000 non-null   object
#  12  existing_loans_count  1000 non-null   int64
#  13  job                   1000 non-null   object
#  14  dependents            1000 non-null   int64
#  15  phone                 1000 non-null   object
#  16  default               1000 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 132.9+ KB

# %%
cat=[]
num=[]
for i in df.drop('default', axis=1).columns:
    if(df[i].dtype=='object'):
        cat.append(i)
    else:
        num.append(i)

# %%
cat
# Out:
# ['checking_balance',
#  'credit_history',
#  'purpose',
#  'savings_balance',
#  'employment_duration',
#  'other_credit',
#  'housing',
#  'job',
#  'phone']

# %%
num
# Out:
# ['months_loan_duration',
#  'amount',
#  'percent_of_income',
#  'years_at_residence',
#  'age',
#  'existing_loans_count',
#  'dependents']

# %%
for i in cat:
    print(df[i].value_counts())
    print()
# Out:
# checking_balance
# unknown       394
# < 0 DM        274
# 1 - 200 DM    269
# > 200 DM       63
# Name: count, dtype: int64
#
# credit_history
# good         530
# critical     293
# poor          88
# very good     49
# perfect       40
# Name: count, dtype: int64
#
# purpose
# furniture/appliances    473
# car                     337
# business                 97
# education                59
# renovations              22
# car0                     12
# Name: count, dtype: int64
#
# savings_balance
# < 100 DM         603
# unknown          183
# 100 - 500 DM     103
# 500 - 1000 DM     63
# > 1000 DM         48
# Name: count, dtype: int64
#
# employment_duration
# 1 - 4 years    339
# > 7 years      253
# 4 - 7 years    174
# < 1 year       172
# unemployed      62
# Name: count, dtype: int64
#
# other_credit
# none     814
# bank     139
# store     47
# Name: count, dtype: int64
#
# housing
# own      713
# rent     179
# other    108
# Name: count, dtype: int64
#
# job
# skilled       630
# unskilled     200
# management    148
# unemployed     22
# Name: count, dtype: int64
#
# phone
# no     596
# yes    404
# Name: count, dtype: int64

# %%
df['purpose'].replace('car0', 'car', inplace=True)

# %%
data=df.copy()

# %%
data_encoded=pd.get_dummies(data, columns=cat)

# %%
data_encoded
# Out:
#      months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                       6    1169                  4                   4   67
# 1                      48    5951                  2                   2   22
# 2                      12    2096                  2                   3   49
# 3                      42    7882                  2                   4   45
# 4                      24    4870                  3                   4   53
# ..                    ...     ...                ...                 ...  ...
# 995                    12    1736                  3                   4   31
# 996                    30    3857                  4                   4   40
# 997                    12     804                  4                   4   38
# 998                    45    1845                  4                   4   23
# 999                    45    4576                  3                   4   27
#
#      existing_loans_count  dependents default  checking_balance_1 - 200 DM  \
# 0                       2           1      no                        False
# 1                       1           1     yes                         True
# 2                       1           2      no                        False
# 3                       1           2      no                        False
# 4                       2           2     yes                        False
# ..                    ...         ...     ...                          ...
# 995                     1           1      no                        False
# 996                     1           1      no                        False
# 997                     1           1      no                        False
# 998                     1           1     yes                        False
# 999                     1           1      no                         True
#
#      checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                       True                      False
# 1                      False                      False
# 2                      False                      False
# 3                       True                      False
# 4                       True                      False
# ..                       ...                        ...
# 995                    False                      False
# 996                     True                      False
# 997                    False                      False
# 998                     True                      False
# 999                    False                      False
#
#      checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                       False                     True                False
# 1                       False                    False                 True
# 2                        True                     True                False
# 3                       False                    False                 True
# 4                       False                    False                False
# ..                        ...                      ...                  ...
# 995                      True                    False                 True
# 996                     False                    False                 True
# 997                      True                    False                 True
# 998                     False                    False                 True
# 999                     False                     True                False
#
#      credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                     False                False                     False
# 1                     False                False                     False
# 2                     False                False                     False
# 3                     False                False                     False
# 4                     False                 True                     False
# ..                      ...                  ...                       ...
# 995                   False                False                     False
# 996                   False                False                     False
# 997                   False                False                     False
# 998                   False                False                     False
# 999                   False                False                     False
#
#      purpose_business  purpose_car  purpose_education  \
# 0               False        False              False
# 1               False        False              False
# 2               False        False               True
# 3               False        False              False
# 4               False         True              False
# ..                ...          ...                ...
# 995             False        False              False
# 996             False         True              False
# 997             False        False              False
# 998             False        False              False
# 999             False         True              False
#
#      purpose_furniture/appliances  purpose_renovations  \
# 0                            True                False
# 1                            True                False
# 2                           False                False
# 3                            True                False
# 4                           False                False
# ..                            ...                  ...
# 995                          True                False
# 996                         False                False
# 997                          True                False
# 998                          True                False
# 999                         False                False
#
#      savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
# ..                            ...                            ...
# 995                         False                          False
# 996                         False                          False
# 997                         False                          False
# 998                         False                          False
# 999                          True                          False
#
#      savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                       False                      False
# 1                        True                      False
# 2                        True                      False
# 3                        True                      False
# 4                        True                      False
# ..                        ...                        ...
# 995                      True                      False
# 996                      True                      False
# 997                      True                      False
# 998                      True                      False
# 999                     False                      False
#
#      savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                       True                            False
# 1                      False                             True
# 2                      False                            False
# 3                      False                            False
# 4                      False                             True
# ..                       ...                              ...
# 995                    False                            False
# 996                    False                             True
# 997                    False                            False
# 998                    False                             True
# 999                    False                            False
#
#      employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                              False                         False
# 1                              False                         False
# 2                               True                         False
# 3                               True                         False
# 4                              False                         False
# ..                               ...                           ...
# 995                             True                         False
# 996                            False                         False
# 997                            False                         False
# 998                            False                         False
# 999                            False                         False
#
#      employment_duration_> 7 years  employment_duration_unemployed  \
# 0                             True                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ..                             ...                             ...
# 995                          False                           False
# 996                          False                           False
# 997                           True                           False
# 998                          False                           False
# 999                          False                            True
#
#      other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0                False               True               False          False
# 1                False               True               False          False
# 2                False               True               False          False
# 3                False               True               False           True
# 4                False               True               False           True
# ..                 ...                ...                 ...            ...
# 995              False               True               False          False
# 996              False               True               False          False
# 997              False               True               False          False
# 998              False               True               False           True
# 999              False               True               False          False
#
#      housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0           True         False           False         True           False
# 1           True         False           False         True           False
# 2           True         False           False        False           False
# 3          False         False           False         True           False
# 4          False         False           False         True           False
# ..           ...           ...             ...          ...             ...
# 995         True         False           False        False           False
# 996         True         False            True        False           False
# 997         True         False           False         True           False
# 998        False         False           False         True           False
# 999         True         False           False         True           False
#
#      job_unskilled  phone_no  phone_yes
# 0            False     False       True
# 1            False      True      False
# 2             True      True      False
# 3            False      True      False
# 4            False      True      False
# ..             ...       ...        ...
# 995           True      True      False
# 996          False     False       True
# 997          False      True      False
# 998          False     False       True
# 999          False      True      False
#
# [1000 rows x 44 columns]

# %%
pd.set_option('display.max_column', None)

# %%
data_encoded
# Out:
#      months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                       6    1169                  4                   4   67
# 1                      48    5951                  2                   2   22
# 2                      12    2096                  2                   3   49
# 3                      42    7882                  2                   4   45
# 4                      24    4870                  3                   4   53
# ..                    ...     ...                ...                 ...  ...
# 995                    12    1736                  3                   4   31
# 996                    30    3857                  4                   4   40
# 997                    12     804                  4                   4   38
# 998                    45    1845                  4                   4   23
# 999                    45    4576                  3                   4   27
#
#      existing_loans_count  dependents default  checking_balance_1 - 200 DM  \
# 0                       2           1      no                        False
# 1                       1           1     yes                         True
# 2                       1           2      no                        False
# 3                       1           2      no                        False
# 4                       2           2     yes                        False
# ..                    ...         ...     ...                          ...
# 995                     1           1      no                        False
# 996                     1           1      no                        False
# 997                     1           1      no                        False
# 998                     1           1     yes                        False
# 999                     1           1      no                         True
#
#      checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                       True                      False
# 1                      False                      False
# 2                      False                      False
# 3                       True                      False
# 4                       True                      False
# ..                       ...                        ...
# 995                    False                      False
# 996                     True                      False
# 997                    False                      False
# 998                     True                      False
# 999                    False                      False
#
#      checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                       False                     True                False
# 1                       False                    False                 True
# 2                        True                     True                False
# 3                       False                    False                 True
# 4                       False                    False                False
# ..                        ...                      ...                  ...
# 995                      True                    False                 True
# 996                     False                    False                 True
# 997                      True                    False                 True
# 998                     False                    False                 True
# 999                     False                     True                False
#
#      credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                     False                False                     False
# 1                     False                False                     False
# 2                     False                False                     False
# 3                     False                False                     False
# 4                     False                 True                     False
# ..                      ...                  ...                       ...
# 995                   False                False                     False
# 996                   False                False                     False
# 997                   False                False                     False
# 998                   False                False                     False
# 999                   False                False                     False
#
#      purpose_business  purpose_car  purpose_education  \
# 0               False        False              False
# 1               False        False              False
# 2               False        False               True
# 3               False        False              False
# 4               False         True              False
# ..                ...          ...                ...
# 995             False        False              False
# 996             False         True              False
# 997             False        False              False
# 998             False        False              False
# 999             False         True              False
#
#      purpose_furniture/appliances  purpose_renovations  \
# 0                            True                False
# 1                            True                False
# 2                           False                False
# 3                            True                False
# 4                           False                False
# ..                            ...                  ...
# 995                          True                False
# 996                         False                False
# 997                          True                False
# 998                          True                False
# 999                         False                False
#
#      savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
# ..                            ...                            ...
# 995                         False                          False
# 996                         False                          False
# 997                         False                          False
# 998                         False                          False
# 999                          True                          False
#
#      savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                       False                      False
# 1                        True                      False
# 2                        True                      False
# 3                        True                      False
# 4                        True                      False
# ..                        ...                        ...
# 995                      True                      False
# 996                      True                      False
# 997                      True                      False
# 998                      True                      False
# 999                     False                      False
#
#      savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                       True                            False
# 1                      False                             True
# 2                      False                            False
# 3                      False                            False
# 4                      False                             True
# ..                       ...                              ...
# 995                    False                            False
# 996                    False                             True
# 997                    False                            False
# 998                    False                             True
# 999                    False                            False
#
#      employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                              False                         False
# 1                              False                         False
# 2                               True                         False
# 3                               True                         False
# 4                              False                         False
# ..                               ...                           ...
# 995                             True                         False
# 996                            False                         False
# 997                            False                         False
# 998                            False                         False
# 999                            False                         False
#
#      employment_duration_> 7 years  employment_duration_unemployed  \
# 0                             True                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ..                             ...                             ...
# 995                          False                           False
# 996                          False                           False
# 997                           True                           False
# 998                          False                           False
# 999                          False                            True
#
#      other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0                False               True               False          False
# 1                False               True               False          False
# 2                False               True               False          False
# 3                False               True               False           True
# 4                False               True               False           True
# ..                 ...                ...                 ...            ...
# 995              False               True               False          False
# 996              False               True               False          False
# 997              False               True               False          False
# 998              False               True               False           True
# 999              False               True               False          False
#
#      housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0           True         False           False         True           False
# 1           True         False           False         True           False
# 2           True         False           False        False           False
# 3          False         False           False         True           False
# 4          False         False           False         True           False
# ..           ...           ...             ...          ...             ...
# 995         True         False           False        False           False
# 996         True         False            True        False           False
# 997         True         False           False         True           False
# 998        False         False           False         True           False
# 999         True         False           False         True           False
#
#      job_unskilled  phone_no  phone_yes
# 0            False     False       True
# 1            False      True      False
# 2             True      True      False
# 3            False      True      False
# 4            False      True      False
# ..             ...       ...        ...
# 995           True      True      False
# 996          False     False       True
# 997          False      True      False
# 998          False     False       True
# 999          False      True      False
#
# [1000 rows x 44 columns]

# %%
data_encoded.columns
# Out:
# Index(['months_loan_duration', 'amount', 'percent_of_income',
#        'years_at_residence', 'age', 'existing_loans_count', 'dependents',
#        'default', 'checking_balance_1 - 200 DM', 'checking_balance_< 0 DM',
#        'checking_balance_> 200 DM', 'checking_balance_unknown',
#        'credit_history_critical', 'credit_history_good',
#        'credit_history_perfect', 'credit_history_poor',
#        'credit_history_very good', 'purpose_business', 'purpose_car',
#        'purpose_education', 'purpose_furniture/appliances',
#        'purpose_renovations', 'savings_balance_100 - 500 DM',
#        'savings_balance_500 - 1000 DM', 'savings_balance_< 100 DM',
#        'savings_balance_> 1000 DM', 'savings_balance_unknown',
#        'employment_duration_1 - 4 years', 'employment_duration_4 - 7 years',
#        'employment_duration_< 1 year', 'employment_duration_> 7 years',
#        'employment_duration_unemployed', 'other_credit_bank',
#        'other_credit_none', 'other_credit_store', 'housing_other',
#        'housing_own', 'housing_rent', 'job_management', 'job_skilled',
#        'job_unemployed', 'job_unskilled', 'phone_no', 'phone_yes'],
#       dtype='object')

# %%
data_encoded
# Out:
#      months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                       6    1169                  4                   4   67
# 1                      48    5951                  2                   2   22
# 2                      12    2096                  2                   3   49
# 3                      42    7882                  2                   4   45
# 4                      24    4870                  3                   4   53
# ..                    ...     ...                ...                 ...  ...
# 995                    12    1736                  3                   4   31
# 996                    30    3857                  4                   4   40
# 997                    12     804                  4                   4   38
# 998                    45    1845                  4                   4   23
# 999                    45    4576                  3                   4   27
#
#      existing_loans_count  dependents default  checking_balance_1 - 200 DM  \
# 0                       2           1      no                        False
# 1                       1           1     yes                         True
# 2                       1           2      no                        False
# 3                       1           2      no                        False
# 4                       2           2     yes                        False
# ..                    ...         ...     ...                          ...
# 995                     1           1      no                        False
# 996                     1           1      no                        False
# 997                     1           1      no                        False
# 998                     1           1     yes                        False
# 999                     1           1      no                         True
#
#      checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                       True                      False
# 1                      False                      False
# 2                      False                      False
# 3                       True                      False
# 4                       True                      False
# ..                       ...                        ...
# 995                    False                      False
# 996                     True                      False
# 997                    False                      False
# 998                     True                      False
# 999                    False                      False
#
#      checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                       False                     True                False
# 1                       False                    False                 True
# 2                        True                     True                False
# 3                       False                    False                 True
# 4                       False                    False                False
# ..                        ...                      ...                  ...
# 995                      True                    False                 True
# 996                     False                    False                 True
# 997                      True                    False                 True
# 998                     False                    False                 True
# 999                     False                     True                False
#
#      credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                     False                False                     False
# 1                     False                False                     False
# 2                     False                False                     False
# 3                     False                False                     False
# 4                     False                 True                     False
# ..                      ...                  ...                       ...
# 995                   False                False                     False
# 996                   False                False                     False
# 997                   False                False                     False
# 998                   False                False                     False
# 999                   False                False                     False
#
#      purpose_business  purpose_car  purpose_education  \
# 0               False        False              False
# 1               False        False              False
# 2               False        False               True
# 3               False        False              False
# 4               False         True              False
# ..                ...          ...                ...
# 995             False        False              False
# 996             False         True              False
# 997             False        False              False
# 998             False        False              False
# 999             False         True              False
#
#      purpose_furniture/appliances  purpose_renovations  \
# 0                            True                False
# 1                            True                False
# 2                           False                False
# 3                            True                False
# 4                           False                False
# ..                            ...                  ...
# 995                          True                False
# 996                         False                False
# 997                          True                False
# 998                          True                False
# 999                         False                False
#
#      savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
# ..                            ...                            ...
# 995                         False                          False
# 996                         False                          False
# 997                         False                          False
# 998                         False                          False
# 999                          True                          False
#
#      savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                       False                      False
# 1                        True                      False
# 2                        True                      False
# 3                        True                      False
# 4                        True                      False
# ..                        ...                        ...
# 995                      True                      False
# 996                      True                      False
# 997                      True                      False
# 998                      True                      False
# 999                     False                      False
#
#      savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                       True                            False
# 1                      False                             True
# 2                      False                            False
# 3                      False                            False
# 4                      False                             True
# ..                       ...                              ...
# 995                    False                            False
# 996                    False                             True
# 997                    False                            False
# 998                    False                             True
# 999                    False                            False
#
#      employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                              False                         False
# 1                              False                         False
# 2                               True                         False
# 3                               True                         False
# 4                              False                         False
# ..                               ...                           ...
# 995                             True                         False
# 996                            False                         False
# 997                            False                         False
# 998                            False                         False
# 999                            False                         False
#
#      employment_duration_> 7 years  employment_duration_unemployed  \
# 0                             True                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ..                             ...                             ...
# 995                          False                           False
# 996                          False                           False
# 997                           True                           False
# 998                          False                           False
# 999                          False                            True
#
#      other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0                False               True               False          False
# 1                False               True               False          False
# 2                False               True               False          False
# 3                False               True               False           True
# 4                False               True               False           True
# ..                 ...                ...                 ...            ...
# 995              False               True               False          False
# 996              False               True               False          False
# 997              False               True               False          False
# 998              False               True               False           True
# 999              False               True               False          False
#
#      housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0           True         False           False         True           False
# 1           True         False           False         True           False
# 2           True         False           False        False           False
# 3          False         False           False         True           False
# 4          False         False           False         True           False
# ..           ...           ...             ...          ...             ...
# 995         True         False           False        False           False
# 996         True         False            True        False           False
# 997         True         False           False         True           False
# 998        False         False           False         True           False
# 999         True         False           False         True           False
#
#      job_unskilled  phone_no  phone_yes
# 0            False     False       True
# 1            False      True      False
# 2             True      True      False
# 3            False      True      False
# 4            False      True      False
# ..             ...       ...        ...
# 995           True      True      False
# 996          False     False       True
# 997          False      True      False
# 998          False     False       True
# 999          False      True      False
#
# [1000 rows x 44 columns]

# %%
for i in cat:
    print(df[i].value_counts(normalize=True))
    print()
# Out:
# checking_balance
# unknown       0.394
# < 0 DM        0.274
# 1 - 200 DM    0.269
# > 200 DM      0.063
# Name: proportion, dtype: float64
#
# credit_history
# good         0.530
# critical     0.293
# poor         0.088
# very good    0.049
# perfect      0.040
# Name: proportion, dtype: float64
#
# purpose
# furniture/appliances    0.473
# car                     0.349
# business                0.097
# education               0.059
# renovations             0.022
# Name: proportion, dtype: float64
#
# savings_balance
# < 100 DM         0.603
# unknown          0.183
# 100 - 500 DM     0.103
# 500 - 1000 DM    0.063
# > 1000 DM        0.048
# Name: proportion, dtype: float64
#
# employment_duration
# 1 - 4 years    0.339
# > 7 years      0.253
# 4 - 7 years    0.174
# < 1 year       0.172
# unemployed     0.062
# Name: proportion, dtype: float64
#
# other_credit
# none     0.814
# bank     0.139
# store    0.047
# Name: proportion, dtype: float64
#
# housing
# own      0.713
# rent     0.179
# other    0.108
# Name: proportion, dtype: float64
#
# job
# skilled       0.630
# unskilled     0.200
# management    0.148
# unemployed    0.022
# Name: proportion, dtype: float64
#
# phone
# no     0.596
# yes    0.404
# Name: proportion, dtype: float64

# %%
data_encoded.head()
# Out:
#    months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                     6    1169                  4                   4   67
# 1                    48    5951                  2                   2   22
# 2                    12    2096                  2                   3   49
# 3                    42    7882                  2                   4   45
# 4                    24    4870                  3                   4   53
#
#    existing_loans_count  dependents default  checking_balance_1 - 200 DM  \
# 0                     2           1      no                        False
# 1                     1           1     yes                         True
# 2                     1           2      no                        False
# 3                     1           2      no                        False
# 4                     2           2     yes                        False
#
#    checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                     True                      False
# 1                    False                      False
# 2                    False                      False
# 3                     True                      False
# 4                     True                      False
#
#    checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                     False                     True                False
# 1                     False                    False                 True
# 2                      True                     True                False
# 3                     False                    False                 True
# 4                     False                    False                False
#
#    credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                   False                False                     False
# 1                   False                False                     False
# 2                   False                False                     False
# 3                   False                False                     False
# 4                   False                 True                     False
#
#    purpose_business  purpose_car  purpose_education  \
# 0             False        False              False
# 1             False        False              False
# 2             False        False               True
# 3             False        False              False
# 4             False         True              False
#
#    purpose_furniture/appliances  purpose_renovations  \
# 0                          True                False
# 1                          True                False
# 2                         False                False
# 3                          True                False
# 4                         False                False
#
#    savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                         False                          False
# 1                         False                          False
# 2                         False                          False
# 3                         False                          False
# 4                         False                          False
#
#    savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                     False                      False
# 1                      True                      False
# 2                      True                      False
# 3                      True                      False
# 4                      True                      False
#
#    savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                     True                            False
# 1                    False                             True
# 2                    False                            False
# 3                    False                            False
# 4                    False                             True
#
#    employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                            False                         False
# 1                            False                         False
# 2                             True                         False
# 3                             True                         False
# 4                            False                         False
#
#    employment_duration_> 7 years  employment_duration_unemployed  \
# 0                           True                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
#
#    other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0              False               True               False          False
# 1              False               True               False          False
# 2              False               True               False          False
# 3              False               True               False           True
# 4              False               True               False           True
#
#    housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0         True         False           False         True           False
# 1         True         False           False         True           False
# 2         True         False           False        False           False
# 3        False         False           False         True           False
# 4        False         False           False         True           False
#
#    job_unskilled  phone_no  phone_yes
# 0          False     False       True
# 1          False      True      False
# 2           True      True      False
# 3          False      True      False
# 4          False      True      False

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   months_loan_duration             1000 non-null   int64
#  1   amount                           1000 non-null   int64
#  2   percent_of_income                1000 non-null   int64
#  3   years_at_residence               1000 non-null   int64
#  4   age                              1000 non-null   int64
#  5   existing_loans_count             1000 non-null   int64
#  6   dependents                       1000 non-null   int64
#  7   default                          1000 non-null   object
#  8   checking_balance_1 - 200 DM      1000 non-null   bool
#  9   checking_balance_< 0 DM          1000 non-null   bool
#  10  checking_balance_> 200 DM        1000 non-null   bool
#  11  checking_balance_unknown         1000 non-null   bool
#  12  credit_history_critical          1000 non-null   bool
#  13  credit_history_good              1000 non-null   bool
#  14  credit_history_perfect           1000 non-null   bool
#  15  credit_history_poor              1000 non-null   bool
#  16  credit_history_very good         1000 non-null   bool
#  17  purpose_business                 1000 non-null   bool
#  18  purpose_car                      1000 non-null   bool
#  19  purpose_education                1000 non-null   bool
#  20  purpose_furniture/appliances     1000 non-null   bool
#  21  purpose_renovations              1000 non-null   bool
#  22  savings_balance_100 - 500 DM     1000 non-null   bool
#  23  savings_balance_500 - 1000 DM    1000 non-null   bool
#  24  savings_balance_< 100 DM         1000 non-null   bool
#  25  savings_balance_> 1000 DM        1000 non-null   bool
#  26  savings_balance_unknown          1000 non-null   bool
#  27  employment_duration_1 - 4 years  1000 non-null   bool
#  28  employment_duration_4 - 7 years  1000 non-null   bool
#  29  employment_duration_< 1 year     1000 non-null   bool
#  30  employment_duration_> 7 years    1000 non-null   bool
#  31  employment_duration_unemployed   1000 non-null   bool
#  32  other_credit_bank                1000 non-null   bool
#  33  other_credit_none                1000 non-null   bool
#  34  other_credit_store               1000 non-null   bool
#  35  housing_other                    1000 non-null   bool
#  36  housing_own                      1000 non-null   bool
#  37  housing_rent                     1000 non-null   bool
#  38  job_management                   1000 non-null   bool
#  39  job_skilled                      1000 non-null   bool
#  40  job_unemployed                   1000 non-null   bool
#  41  job_unskilled                    1000 non-null   bool
#  42  phone_no                         1000 non-null   bool
#  43  phone_yes                        1000 non-null   bool
# dtypes: bool(36), int64(7), object(1)
# memory usage: 97.8+ KB

# %%
x=data_encoded.drop('default', axis=1)
y=data_encoded['default']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=1)

# %% [markdown]
# #### Building Decision Tree model

# %%
dt_model=DecisionTreeClassifier()

# %%
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
def evaluate_train_model(model):
    y_train_predict = model.predict(x_train)

    Acc_train = print(model.score(x_train,y_train))

    CM_train = print(sns.heatmap((metrics.confusion_matrix(y_train,y_train_predict)),annot=True,fmt='.5g'
                ,cmap='Blues'));
    plt.xlabel('Predicted');
    plt.ylabel('Actuals',rotation=0);
    plt.title('CONFUSION MATRIX - CUT OFF (0.5)')

    CR_train = print(metrics.classification_report(y_train,y_train_predict))

    probs = model.predict_proba(x_train)
    probs = probs[:, 1]
    auc_train = roc_auc_score(y_train, probs)
    
    return Acc_train,CM_train,CR_train,auc_train

# %%
evaluate_train_model(dt_model)
# Out:
# 1.0
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#           no       1.00      1.00      1.00       486
#          yes       1.00      1.00      1.00       214
#
#     accuracy                           1.00       700
#    macro avg       1.00      1.00      1.00       700
# weighted avg       1.00      1.00      1.00       700
# (None, None, None, 1.0)

# %%
def evaluate_test_model(model):
    y_test_predict = model.predict(x_test)

    Acc_test = print("The accuracy of the model is {}".format(model.score(x_test,y_test)))

    CM_test = print(sns.heatmap((metrics.confusion_matrix(y_test,y_test_predict)),annot=True,fmt='.5g'
                ,cmap='Blues'));
    plt.xlabel('Predicted');
    plt.ylabel('Actuals',rotation=0);
    plt.title('CONFUSION MATRIX - CUT OFF (0.5)')

    CR_test = print(metrics.classification_report(y_test,y_test_predict))

    probs = model.predict_proba(x_test)
    probs = probs[:, 1]
    auc_test = roc_auc_score(y_test, probs)
    
    return Acc_test,CM_test,CR_test,auc_test

# %%
evaluate_test_model(dt_model)
# Out:
# The accuracy of the model is 0.6566666666666666
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#           no       0.76      0.76      0.76       214
#          yes       0.40      0.40      0.40        86
#
#     accuracy                           0.66       300
#    macro avg       0.58      0.58      0.58       300
# weighted avg       0.66      0.66      0.66       300
# (None, None, None, 0.5785155400999783)

# %%
x
# Out:
#      months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                       6    1169                  4                   4   67
# 1                      48    5951                  2                   2   22
# 2                      12    2096                  2                   3   49
# 3                      42    7882                  2                   4   45
# 4                      24    4870                  3                   4   53
# ..                    ...     ...                ...                 ...  ...
# 995                    12    1736                  3                   4   31
# 996                    30    3857                  4                   4   40
# 997                    12     804                  4                   4   38
# 998                    45    1845                  4                   4   23
# 999                    45    4576                  3                   4   27
#
#      existing_loans_count  dependents  checking_balance_1 - 200 DM  \
# 0                       2           1                        False
# 1                       1           1                         True
# 2                       1           2                        False
# 3                       1           2                        False
# 4                       2           2                        False
# ..                    ...         ...                          ...
# 995                     1           1                        False
# 996                     1           1                        False
# 997                     1           1                        False
# 998                     1           1                        False
# 999                     1           1                         True
#
#      checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                       True                      False
# 1                      False                      False
# 2                      False                      False
# 3                       True                      False
# 4                       True                      False
# ..                       ...                        ...
# 995                    False                      False
# 996                     True                      False
# 997                    False                      False
# 998                     True                      False
# 999                    False                      False
#
#      checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                       False                     True                False
# 1                       False                    False                 True
# 2                        True                     True                False
# 3                       False                    False                 True
# 4                       False                    False                False
# ..                        ...                      ...                  ...
# 995                      True                    False                 True
# 996                     False                    False                 True
# 997                      True                    False                 True
# 998                     False                    False                 True
# 999                     False                     True                False
#
#      credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                     False                False                     False
# 1                     False                False                     False
# 2                     False                False                     False
# 3                     False                False                     False
# 4                     False                 True                     False
# ..                      ...                  ...                       ...
# 995                   False                False                     False
# 996                   False                False                     False
# 997                   False                False                     False
# 998                   False                False                     False
# 999                   False                False                     False
#
#      purpose_business  purpose_car  purpose_education  \
# 0               False        False              False
# 1               False        False              False
# 2               False        False               True
# 3               False        False              False
# 4               False         True              False
# ..                ...          ...                ...
# 995             False        False              False
# 996             False         True              False
# 997             False        False              False
# 998             False        False              False
# 999             False         True              False
#
#      purpose_furniture/appliances  purpose_renovations  \
# 0                            True                False
# 1                            True                False
# 2                           False                False
# 3                            True                False
# 4                           False                False
# ..                            ...                  ...
# 995                          True                False
# 996                         False                False
# 997                          True                False
# 998                          True                False
# 999                         False                False
#
#      savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
# ..                            ...                            ...
# 995                         False                          False
# 996                         False                          False
# 997                         False                          False
# 998                         False                          False
# 999                          True                          False
#
#      savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                       False                      False
# 1                        True                      False
# 2                        True                      False
# 3                        True                      False
# 4                        True                      False
# ..                        ...                        ...
# 995                      True                      False
# 996                      True                      False
# 997                      True                      False
# 998                      True                      False
# 999                     False                      False
#
#      savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                       True                            False
# 1                      False                             True
# 2                      False                            False
# 3                      False                            False
# 4                      False                             True
# ..                       ...                              ...
# 995                    False                            False
# 996                    False                             True
# 997                    False                            False
# 998                    False                             True
# 999                    False                            False
#
#      employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                              False                         False
# 1                              False                         False
# 2                               True                         False
# 3                               True                         False
# 4                              False                         False
# ..                               ...                           ...
# 995                             True                         False
# 996                            False                         False
# 997                            False                         False
# 998                            False                         False
# 999                            False                         False
#
#      employment_duration_> 7 years  employment_duration_unemployed  \
# 0                             True                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ..                             ...                             ...
# 995                          False                           False
# 996                          False                           False
# 997                           True                           False
# 998                          False                           False
# 999                          False                            True
#
#      other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0                False               True               False          False
# 1                False               True               False          False
# 2                False               True               False          False
# 3                False               True               False           True
# 4                False               True               False           True
# ..                 ...                ...                 ...            ...
# 995              False               True               False          False
# 996              False               True               False          False
# 997              False               True               False          False
# 998              False               True               False           True
# 999              False               True               False          False
#
#      housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0           True         False           False         True           False
# 1           True         False           False         True           False
# 2           True         False           False        False           False
# 3          False         False           False         True           False
# 4          False         False           False         True           False
# ..           ...           ...             ...          ...             ...
# 995         True         False           False        False           False
# 996         True         False            True        False           False
# 997         True         False           False         True           False
# 998        False         False           False         True           False
# 999         True         False           False         True           False
#
#      job_unskilled  phone_no  phone_yes
# 0            False     False       True
# 1            False      True      False
# 2             True      True      False
# 3            False      True      False
# 4            False      True      False
# ..             ...       ...        ...
# 995           True      True      False
# 996          False     False       True
# 997          False      True      False
# 998          False     False       True
# 999          False      True      False
#
# [1000 rows x 43 columns]

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, feature_names=x.columns, class_names=["Default_Yes", "Default_No"], filled=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[110], line 3
#       1 from sklearn.tree import DecisionTreeClassifier, plot_tree
#       2 plt.figure(figsize=(12, 8))
# ----> 3 plot_tree(dt_model, feature_names=x.columns, class_names=["Default_Yes", "Default_No"], filled=True)
#       4 plt.show()
#
# File c:\Tools\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# File c:\Tools\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'feature_names' parameter of plot_tree must be an instance of 'list' or None. Got Index(['months_loan_duration', 'amount', 'percent_of_income',
#        'years_at_residence', 'age', 'existing_loans_count', 'dependents',
#        'checking_balance_1 - 200 DM', 'checking_balance_< 0 DM',
#        'checking_balance_> 200 DM', 'checking_balance_unknown',
#        'credit_history_critical', 'credit_history_good',
#        'credit_history_perfect', 'credit_history_poor',
#        'credit_history_very good', 'purpose_business', 'purpose_car',
#        'purpose_education', 'purpose_furniture/appliances',
#        'purpose_renovations', 'savings_balance_100 - 500 DM',
#        'savings_balance_500 - 1000 DM', 'savings_balance_< 100 DM',
#        'savings_balance_> 1000 DM', 'savings_balance_unknown',
#        'employment_duration_1 - 4 years', 'employment_duration_4 - 7 years',
#        'employment_duration_< 1 year', 'employment_duration_> 7 years',
#        'employment_duration_unemployed', 'other_credit_bank',
#        'other_credit_none', 'other_credit_store', 'housing_other',
#        'housing_own', 'housing_rent', 'job_management', 'job_skilled',
#        'job_unemployed', 'job_unskilled', 'phone_no', 'phone_yes'],
#       dtype='object') instead.

# %% [markdown]
# #### Variable importance

# %%
pd.DataFrame(dt_model.feature_importances_*100, index=x.columns).sort_values(by=0, ascending=False)
# Out:
#                                          0
# amount                           18.029629
# months_loan_duration             11.291103
# age                              11.111120
# checking_balance_unknown          9.815739
# years_at_residence                5.064941
# credit_history_critical           3.487184
# percent_of_income                 3.361958
# employment_duration_> 7 years     3.106184
# purpose_car                       3.016612
# checking_balance_< 0 DM           2.652791
# savings_balance_< 100 DM          2.415032
# credit_history_poor               2.011675
# job_unskilled                     1.773993
# employment_duration_1 - 4 years   1.738684
# other_credit_none                 1.713898
# existing_loans_count              1.708263
# employment_duration_< 1 year      1.483807
# credit_history_good               1.343645
# checking_balance_1 - 200 DM       1.318058
# housing_own                       1.222709
# credit_history_perfect            1.220649
# housing_rent                      1.124423
# purpose_business                  1.122078
# dependents                        1.101320
# employment_duration_unemployed    0.899601
# purpose_renovations               0.849105
# employment_duration_4 - 7 years   0.815819
# phone_no                          0.717921
# savings_balance_500 - 1000 DM     0.684269
# other_credit_store                0.616963
# job_management                    0.576901
# credit_history_very good          0.576901
# savings_balance_> 1000 DM         0.568748
# job_unemployed                    0.504788
# phone_yes                         0.504788
# savings_balance_100 - 500 DM      0.448701
# housing_other                     0.000000
# other_credit_bank                 0.000000
# savings_balance_unknown           0.000000
# job_skilled                       0.000000
# purpose_furniture/appliances      0.000000
# purpose_education                 0.000000
# checking_balance_> 200 DM         0.000000

# %% [markdown]
# #### Decision-Tree pruning --> Customizing the decison tree

# %%
# Study through gpt
dt_model_pruning=DecisionTreeClassifier(
    criterion="gini", 
    max_depth=7, 
    min_samples_leaf=30,
    min_samples_split=20,
    # class_weight={False:0.4, True: 0.6} 
)

# %%
dt_model_pruning.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=30, min_samples_split=20)

# %%
evaluate_train_model(dt_model_pruning)
# Out:
# 0.7557142857142857
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#           no       0.82      0.84      0.83       486
#          yes       0.61      0.57      0.59       214
#
#     accuracy                           0.76       700
#    macro avg       0.71      0.70      0.71       700
# weighted avg       0.75      0.76      0.75       700
# (None, None, None, 0.8120024229837314)

# %%
dt_model_pruning2=DecisionTreeClassifier(
    criterion="gini", 
    max_depth=7, 
    min_samples_leaf=30,
    min_samples_split=20,
)

# %%
dt_model_pruning2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=30, min_samples_split=20)

# %%
evaluate_train_model(dt_model_pruning2)
# Out:
# 0.7557142857142857
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#           no       0.82      0.84      0.83       486
#          yes       0.61      0.57      0.59       214
#
#     accuracy                           0.76       700
#    macro avg       0.71      0.70      0.71       700
# weighted avg       0.75      0.76      0.75       700
# (None, None, None, 0.8120024229837314)

# %%
evaluate_test_model(dt_model_pruning2)
# Out:
# The accuracy of the model is 0.7433333333333333
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#           no       0.80      0.85      0.82       214
#          yes       0.56      0.49      0.52        86
#
#     accuracy                           0.74       300
#    macro avg       0.68      0.67      0.67       300
# weighted avg       0.73      0.74      0.74       300
# (None, None, None, 0.7205498804607694)

# %% [markdown]
# #### Running Grid Search

# %%
param_grid={
    'criterion':['gini', 'entropy', 'log_loss'],
    'max_depth': range(5, 16),
    'min_samples_split': range(10, 30),
    'min_samples_leaf':range(10, 20),
    # 'min_features':['None', 'sqrt', 'log2']
}
# Initialize GridSearchCV
Grid_Search=GridSearchCV(
    estimator=dt_model,
    param_grid=param_grid,
    cv=5,
    scoring='recall',
    n_jobs=1,
    verbose=1
)
Grid_Search.fit(x_train, y_train)
best_grid=Grid_Search.best_estimator_
# Out:
# Fitting 5 folds for each of 6600 candidates, totalling 33000 fits

# %%
evaluate_train_model(best_grid)
# Out:
# 0.7628571428571429
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#           no       0.76      0.97      0.85       486
#          yes       0.80      0.30      0.44       214
#
#     accuracy                           0.76       700
#    macro avg       0.78      0.63      0.64       700
# weighted avg       0.77      0.76      0.72       700
# (None, None, None, 0.8304151763393716)

# %%
evaluate_test_model(best_grid)
# Out:
# The accuracy of the model is 0.7166666666666667
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#           no       0.74      0.94      0.83       214
#          yes       0.52      0.16      0.25        86
#
#     accuracy                           0.72       300
#    macro avg       0.63      0.55      0.54       300
# weighted avg       0.67      0.72      0.66       300
# (None, None, None, 0.6798250380352098)
